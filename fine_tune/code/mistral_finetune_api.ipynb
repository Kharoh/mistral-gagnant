# %% [markdown]
# # Mistral Fine-tuning API
#
# Check out the docs: https://docs.mistral.ai/capabilities/finetuning/

# %%
# !pip install mistralai pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mistralai
#   Downloading mistralai-1.2.3-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: pandas in c:\users\lucas\appdata\roaming\python\python310\site-packages (2.1.3)
# Collecting eval-type-backport<0.3.0,>=0.2.0 (from mistralai)
#   Downloading eval_type_backport-0.2.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in c:\users\lucas\appdata\roaming\python\python310\site-packages (from mistralai) (0.27.2)
# Collecting jsonpath-python<2.0.0,>=1.0.6 (from mistralai)
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\program files\python310\lib\site-packages (from mistralai) (2.9.2)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\users\lucas\appdata\roaming\python\python310\site-packages (from mistralai) (2.8.2)
# Requirement already satisfied: typing-inspect<0.10.0,>=0.9.0 in c:\users\lucas\appdata\roaming\python\python310\site-packages (from mistralai) (0.9.0)
# Requirement already satisfied: six>=1.5 in c:\users\lucas\appdata\roaming\python\python310\site-packages (from python-dateutil==2.8.2->mistralai) (1.16.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\program files\python310\lib\site-packages (from pandas) (1.23.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lucas\appdata\roaming\python\python310\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lucas\appdata\roaming\python\python310\site-packages (from pandas) (2023.3)
# Requirement already satisfied: anyio in c:\users\lucas\appdata\roaming\python\python310\site-packages (from httpx<0.28.0,>=0.27.0->mistralai) (4.6.2.post1)
# Requirement already satisfied: certifi in c:\users\lucas\appdata\roaming\python\python310\site-packages (from httpx<0.28.0,>=0.27.0->mistralai) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in c:\users\lucas\appdata\roaming\python\python310\site-packages (from httpx<0.28.0,>=0.27.0->mistralai) (1.0.6)
# Requirement already satisfied: idna in c:\users\lucas\appdata\roaming\python\python310\site-packages (from httpx<0.28.0,>=0.27.0->mistralai) (3.4)
# Requirement already satisfied: sniffio in c:\users\lucas\appdata\roaming\python\python310\site-packages (from httpx<0.28.0,>=0.27.0->mistralai) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\lucas\appdata\roaming\python\python310\site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->mistralai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\program files\python310\lib\site-packages (from pydantic<3.0.0,>=2.9.0->mistralai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\program files\python310\lib\site-packages (from pydantic<3.0.0,>=2.9.0->mistralai) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\lucas\appdata\roaming\python\python310\site-packages (from pydantic<3.0.0,>=2.9.0->mistralai) (4.12.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\lucas\appdata\roaming\python\python310\site-packages (from typing-inspect<0.10.0,>=0.9.0->mistralai) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\lucas\appdata\roaming\python\python310\site-packages (from anyio->httpx<0.28.0,>=0.27.0->mistralai) (1.2.0)
# Downloading mistralai-1.2.3-py3-none-any.whl (256 kB)
# Downloading eval_type_backport-0.2.0-py3-none-any.whl (5.9 kB)
# Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Installing collected packages: jsonpath-python, eval-type-backport, mistralai
# Successfully installed eval-type-backport-0.2.0 jsonpath-python-1.0.6 mistralai-1.2.3
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Prepare the dataset
#
# In this example, let’s use the ultrachat_200k dataset. We load a chunk of the data into Pandas Dataframes, split the data into training and validation, and save the data into the required jsonl format for fine-tuning.

# %%
import pandas as pd
df = pd.read_csv('../dataset/amazon.csv')
df_train=df.sample(frac=0.995,random_state=200)
df_eval=df.drop(df_train.index)

df_train.to_json("ultrachat_chunk_train.jsonl", orient="records", lines=True)
df_eval.to_json("ultrachat_chunk_eval.jsonl", orient="records", lines=True)

# %%
# !ls -lh
# Out:
# 'ls' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.

# %% [markdown]
# ## Reformat dataset
# If you upload this ultrachat_chunk_train.jsonl to Mistral API, you might encounter an error message “Invalid file format” due to data formatting issues. To reformat the data into the correct format, you can download the reformat_dataset.py script and use it to validate and reformat both the training and evaluation data:

# %%
# download the validation and reformat script
# !wget https://raw.githubusercontent.com/mistralai/mistral-finetune/main/utils/reformat_data.py
# Out:
# 'wget' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.

# %%
# validate and reformat the training data
# !python reformat_data.py ultrachat_chunk_train.jsonl

# %%
# validate the reformat the eval data
# !python reformat_data.py ultrachat_chunk_eval.jsonl

# %%
# df_train.iloc[3674]['messages']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_train.iloc[3674]['messages']
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexing.py:1714, in _iLocIndexer._getitem_axis(self, key, axis)
#    1711     raise TypeError("Cannot index by location index with a non-integer key")
#    1713 # validate the location
# -> 1714 self._validate_integer(key, axis)
#    1716 return self.obj._ixs(key, axis=axis)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexing.py:1647, in _iLocIndexer._validate_integer(self, key, axis)
#    1645 len_axis = len(self.obj._get_axis(axis))
#    1646 if key >= len_axis or key < -len_axis:
# -> 1647     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# ## Upload dataset

# %%
from mistralai import Mistral
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("MISTRAL_API_KEY")

client = Mistral(api_key=api_key)

ultrachat_chunk_eval = client.files.upload(file={
    "file_name": "reformatted_ultrachat_chunk_eval.jsonl",
    "content": open("ultrachat_chunk_eval.jsonl", "rb"),
})
ultrachat_chunk_train = client.files.upload(file={
    "file_name": "reformatted_ultrachat_chunk_train.jsonl",
    "content": open("ultrachat_chunk_train.jsonl", "rb"),
})
# Out:
# ---------------------------------------------------------------------------
# SDKError                                  Traceback (most recent call last)
# Cell In[18], line 11
#       7 api_key = os.getenv("MISTRAL_API_KEY")
#       9 client = Mistral(api_key=api_key)
# ---> 11 ultrachat_chunk_eval = client.files.upload(file={
#      12     "file_name": "reformatted_ultrachat_chunk_eval.jsonl",
#      13     "content": open("ultrachat_chunk_eval.jsonl", "rb"),
#      14 })
#      15 ultrachat_chunk_train = client.files.upload(file={
#      16     "file_name": "reformatted_ultrachat_chunk_train.jsonl",
#      17     "content": open("ultrachat_chunk_train.jsonl", "rb"),
#      18 })
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mistralai\files.py:98, in Files.upload(self, file, purpose, retries, server_url, timeout_ms)
#      96 if utils.match_response(http_res, ["4XX", "5XX"], "*"):
#      97     http_res_text = utils.stream_to_text(http_res)
# ---> 98     raise models.SDKError(
#      99         "API error occurred", http_res.status_code, http_res_text, http_res
#     100     )
#     102 content_type = http_res.headers.get("Content-Type")
#     103 http_res_text = utils.stream_to_text(http_res)
#
# SDKError: API error occurred: Status 422
# {"detail": "Invalid file format.", "description": "Found 7 errors in this file. You can view supported formats here: https://docs.mistral.ai/capabilities/finetuning. ", "errors": [{"message": "1 validation error for FinetuningMessages messages   Input should be a valid list [type=list_type, input_value={'product_id': 'B09V2Q4QV...&s=electronics&sr=1-14'}, input_type=dict]     For further information visit https://errors.pydantic.dev/2.9/v/list_type", "line_number": 1}, {"message": "1 validation error for FinetuningMessages messages   Input should be a valid list [type=list_type, input_value={'product_id': 'B0B2DJ5RV...s=electronics&sr=1-260'}, input_type=dict]     For further information visit https://errors.pydantic.dev/2.9/v/list_type", "line_number": 2}, {"message": "1 validation error for FinetuningMessages messages   Input should be a valid list [type=list_type, input_value={'product_id': 'B00N1U9AJ...96&s=computers&sr=1-36'}, input_type=dict]     For further information visit https://errors.pydantic.dev/2.9/v/list_type", "line_number": 3}, {"message": "1 validation error for FinetuningMessages messages   Input should be a valid list [type=list_type, input_value={'product_id': 'B09W5XR9R...6&s=computers&sr=1-219'}, input_type=dict]     For further information visit https://errors.pydantic.dev/2.9/v/list_type", "line_number": 4}, {"message": "1 validation error for FinetuningMessages messages   Input should be a valid list [type=list_type, input_value={'product_id': 'B07G3YNLJ...7&s=computers&sr=1-247'}, input_type=dict]     For further information visit https://errors.pydantic.dev/2.9/v/list_type", "line_number": 5}, {"message": "1 validation error for FinetuningMessages messages   Input should be a valid list [type=list_type, input_value={'product_id': 'B08K9PX15...8&s=computers&sr=1-285'}, input_type=dict]     For further information visit https://errors.pydantic.dev/2.9/v/list_type", "line_number": 6}, {"message": "1 validation error for FinetuningMessages messages   Input should be a valid list [type=list_type, input_value={'product_id': 'B08MV82R9...596&s=kitchen&sr=1-101'}, input_type=dict]     For further information visit https://errors.pydantic.dev/2.9/v/list_type", "line_number": 7}]}

# %%
import json
def pprint(obj):
    print(json.dumps(obj.dict(), indent=4))

# %%
pprint(ultrachat_chunk_train)
# Out:
# {
#     "id": "c6a8fec2-a19d-415f-ad70-c78e95325f1d",
#     "object": "file",
#     "bytes": 121379382,
#     "created_at": 1732359131,
#     "filename": "ultrachat_chunk_train.jsonl",
#     "purpose": "fine-tune",
#     "sample_type": "instruct",
#     "source": "upload",
#     "num_lines": 28156
# }

# %%
pprint(ultrachat_chunk_eval)
# Out:
# {
#     "id": "0d06d17b-587c-4212-81b8-82153a0e2a94",
#     "object": "file",
#     "bytes": 596255,
#     "created_at": 1732359132,
#     "filename": "ultrachat_chunk_eval.jsonl",
#     "purpose": "fine-tune",
#     "sample_type": "instruct",
#     "source": "upload",
#     "num_lines": 142
# }

# %% [markdown]
# ## Create a fine-tuning job

# %%
created_jobs = client.fine_tuning.jobs.create(
    model="open-mistral-7b",
    training_files=[{"file_id": ultrachat_chunk_train.id, "weight": 1}],
    validation_files=[ultrachat_chunk_eval.id],
    hyperparameters={
    "training_steps": 10,
    "learning_rate":0.0001
    },
    auto_start=True
)
created_jobs
# Out:
# JobOut(id='0b0c7fe9-c539-4c83-b525-6fc25392c014', auto_start=True, hyperparameters=TrainingParameters(training_steps=10, learning_rate=0.0001, weight_decay=0.1, warmup_fraction=0.05, epochs=None, fim_ratio=None, seq_len=32768), model='open-mistral-7b', status='QUEUED', job_type='FT', created_at=1732359149, modified_at=1732359149, training_files=['c6a8fec2-a19d-415f-ad70-c78e95325f1d'], validation_files=['0d06d17b-587c-4212-81b8-82153a0e2a94'], OBJECT='job', fine_tuned_model=None, suffix=None, integrations=[], trained_tokens=None, repositories=[], metadata=JobMetadataOut(expected_duration_seconds=None, cost=0.0, cost_currency=None, train_tokens_per_step=None, train_tokens=None, data_tokens=None, estimated_start_time=None))

# %%
pprint(created_jobs)
# Out:
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": null,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359149,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": null,
#         "cost": 0.0,
#         "cost_currency": null,
#         "train_tokens_per_step": null,
#         "train_tokens": null,
#         "data_tokens": null,
#         "estimated_start_time": null
#     }
# }

# %%
jobs = client.fine_tuning.jobs.list()
print(jobs)
# Out:
# total=5 data=[JobOut(id='0b0c7fe9-c539-4c83-b525-6fc25392c014', auto_start=True, hyperparameters=TrainingParameters(training_steps=10, learning_rate=0.0001, weight_decay=0.1, warmup_fraction=0.05, epochs=0.0431941570306258, fim_ratio=None, seq_len=32768), model='open-mistral-7b', status='QUEUED', job_type='FT', created_at=1732359149, modified_at=1732359152, training_files=['c6a8fec2-a19d-415f-ad70-c78e95325f1d'], validation_files=['0d06d17b-587c-4212-81b8-82153a0e2a94'], OBJECT='job', fine_tuned_model=None, suffix=None, integrations=[], trained_tokens=None, repositories=[], metadata=JobMetadataOut(expected_duration_seconds=140, cost=2.5, cost_currency='EUR', train_tokens_per_step=131072, train_tokens=1310720, data_tokens=30344845, estimated_start_time=1732360978)), JobOut(id='f0c1608f-cd6d-400b-bf87-fa52ceaa1530', auto_start=False, hyperparameters=TrainingParameters(training_steps=12, learning_rate=0.0001, weight_decay=0.1, warmup_fraction=0.05, epochs=10.0, fim_ratio=None, seq_len=32768), model='mistral-small-latest', status='VALIDATED', job_type='FT', created_at=1732359090, modified_at=1732359091, training_files=['46ae0fe4-1e50-4ed2-be8d-c77ba92cb902'], validation_files=[], OBJECT='job', fine_tuned_model=None, suffix='', integrations=[], trained_tokens=None, repositories=[], metadata=JobMetadataOut(expected_duration_seconds=264, cost=5.67, cost_currency='EUR', train_tokens_per_step=124219, train_tokens=1490630, data_tokens=149063, estimated_start_time=None)), JobOut(id='513bcf8c-6832-49af-8a0d-9231c9751285', auto_start=False, hyperparameters=TrainingParameters(training_steps=None, learning_rate=0.0001, weight_decay=0.1, warmup_fraction=0.05, epochs=10.0, fim_ratio=None, seq_len=32768), model='mistral-small-latest', status='FAILED_VALIDATION', job_type='FT', created_at=1732359069, modified_at=1732359071, training_files=['9924dff6-3983-4dd2-b48a-9493f923d785'], validation_files=['9924dff6-3983-4dd2-b48a-9493f923d785'], OBJECT='job', fine_tuned_model=None, suffix='', integrations=[], trained_tokens=None, repositories=[], metadata=JobMetadataOut(expected_duration_seconds=None, cost=0.0, cost_currency=None, train_tokens_per_step=None, train_tokens=None, data_tokens=None, estimated_start_time=None)), JobOut(id='8a78d7d9-6dde-473f-972f-34faa178ca2b', auto_start=True, hyperparameters=TrainingParameters(training_steps=10, learning_rate=0.0001, weight_decay=0.1, warmup_fraction=0.05, epochs=0.0431941570306258, fim_ratio=None, seq_len=32768), model='open-mistral-7b', status='QUEUED', job_type='FT', created_at=1732358921, modified_at=1732358923, training_files=['9924dff6-3983-4dd2-b48a-9493f923d785'], validation_files=['46ae0fe4-1e50-4ed2-be8d-c77ba92cb902'], OBJECT='job', fine_tuned_model=None, suffix=None, integrations=[], trained_tokens=None, repositories=[], metadata=JobMetadataOut(expected_duration_seconds=140, cost=2.5, cost_currency='EUR', train_tokens_per_step=131072, train_tokens=1310720, data_tokens=30344845, estimated_start_time=1732360838)), JobOut(id='81a1cc5c-91bf-4a38-8d65-8f9f275e7e9b', auto_start=True, hyperparameters=TrainingParameters(training_steps=10, learning_rate=0.0001, weight_decay=0.1, warmup_fraction=0.05, epochs=0.0431941570306258, fim_ratio=None, seq_len=32768), model='open-mistral-7b', status='QUEUED', job_type='FT', created_at=1732358877, modified_at=1732358878, training_files=['41a778a4-7fcc-46a2-a06c-1a769fea74d5'], validation_files=['0e2036ee-ed8f-47c0-ab0b-6b4e787d87c1'], OBJECT='job', fine_tuned_model=None, suffix=None, integrations=[], trained_tokens=None, repositories=[], metadata=JobMetadataOut(expected_duration_seconds=140, cost=2.5, cost_currency='EUR', train_tokens_per_step=131072, train_tokens=1310720, data_tokens=30344845, estimated_start_time=1732360698))] OBJECT='list'

# %%
retrieved_jobs = client.fine_tuning.jobs.get(job_id = created_jobs.id)
retrieved_jobs
# Out:
# DetailedJobOut(id='0b0c7fe9-c539-4c83-b525-6fc25392c014', auto_start=True, hyperparameters=TrainingParameters(training_steps=10, learning_rate=0.0001, weight_decay=0.1, warmup_fraction=0.05, epochs=0.0431941570306258, fim_ratio=None, seq_len=32768), model='open-mistral-7b', status='QUEUED', job_type='FT', created_at=1732359149, modified_at=1732359152, training_files=['c6a8fec2-a19d-415f-ad70-c78e95325f1d'], validation_files=['0d06d17b-587c-4212-81b8-82153a0e2a94'], OBJECT='job', fine_tuned_model=None, suffix=None, integrations=[], trained_tokens=None, repositories=[], metadata=JobMetadataOut(expected_duration_seconds=140, cost=2.5, cost_currency='EUR', train_tokens_per_step=131072, train_tokens=1310720, data_tokens=30344845, estimated_start_time=1732360980), events=[EventOut(name='status-updated', created_at=1732359152, data={'status': 'QUEUED'}), EventOut(name='status-updated', created_at=1732359152, data={'status': 'VALIDATED'}), EventOut(name='status-updated', created_at=1732359152, data={'status': 'RUNNING'}), EventOut(name='status-updated', created_at=1732359149, data={'status': 'QUEUED'})], checkpoints=[])

# %%
import time

retrieved_job = client.fine_tuning.jobs.get(job_id = created_jobs.id)
while retrieved_job.status in ["RUNNING", "QUEUED"]:
    retrieved_job = client.fine_tuning.jobs.get(job_id = created_jobs.id)
    pprint(retrieved_job)
    print(f"Job is {retrieved_job.status}, waiting 10 seconds")
    time.sleep(10)
# Out:
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732360985
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732360995
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361006
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361016
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361026
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361037
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361047
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361057
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361068
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361078
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361089
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361099
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361109
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361120
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361130
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361141
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361151
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361161
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361172
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361182
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361192
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361203
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361213
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361224
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361234
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361244
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361255
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361265
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361275
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361286
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361296
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# {
#     "id": "0b0c7fe9-c539-4c83-b525-6fc25392c014",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null,
#         "seq_len": 32768
#     },
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1732359149,
#     "modified_at": 1732359152,
#     "training_files": [
#         "c6a8fec2-a19d-415f-ad70-c78e95325f1d"
#     ],
#     "validation_files": [
#         "0d06d17b-587c-4212-81b8-82153a0e2a94"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 140,
#         "cost": 2.5,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": 1732361307
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359152,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1732359149,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is QUEUED, waiting 10 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-67a9065eac87> in <cell line: 4>()
#       6     pprint(retrieved_job)
#       7     print(f"Job is {retrieved_job.status}, waiting 10 seconds")
# ----> 8     time.sleep(10)
#       9
#
# KeyboardInterrupt:

# %%
# List jobs
jobs = client.fine_tuning.jobs.list()
pprint(jobs)
# Out:
# {
#     "total": 32,
#     "data": [
#         {
#             "id": "20178c3c-d75b-428e-b20d-7d39aa2b7468",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "epochs": 0.0431941570306258,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1721405548,
#             "modified_at": 1721405693,
#             "training_files": [
#                 "ec5af16a-77fe-4e14-ad09-47ead2848ce6"
#             ],
#             "validation_files": [
#                 "d0c643a2-a57c-4031-bda7-5c9d6c3ec3e4"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:b6e34a5e:20240719:20178c3c",
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": 1310720,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 120,
#                 "cost": 2.6214,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 30344845,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "98cbe43b-61e5-47a8-a5fb-57f6d82abc0a",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "epochs": 0.0431941570306258,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1721405463,
#             "modified_at": 1721405603,
#             "training_files": [
#                 "71664e51-eae4-4c5b-9007-2c4586265609"
#             ],
#             "validation_files": [
#                 "6c09517c-32d9-465c-8e4b-4496d1401ba0"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:b6e34a5e:20240719:98cbe43b",
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": 1310720,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 120,
#                 "cost": 2.6214,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 30344845,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "baf7cb65-5ab6-4cdd-a4c6-a6f90c18cd7b",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "epochs": 0.0431941570306258,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1721396928,
#             "modified_at": 1721397062,
#             "training_files": [
#                 "96d5e16c-d701-455c-8f76-82054d005325"
#             ],
#             "validation_files": [
#                 "cfc6dd29-f82e-48c0-8153-59e2313600c8"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:b6e34a5e:20240719:baf7cb65",
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": 1310720,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 100,
#                 "cost": 2.6214,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 30344845,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "7d82092d-a827-4943-9361-b321c6a3809c",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "epochs": 0.0431941570306258,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "VALIDATED",
#             "job_type": "FT",
#             "created_at": 1721396750,
#             "modified_at": 1721396751,
#             "training_files": [
#                 "96d5e16c-d701-455c-8f76-82054d005325"
#             ],
#             "validation_files": [
#                 "cfc6dd29-f82e-48c0-8153-59e2313600c8"
#             ],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 100,
#                 "cost": 2.6214,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 30344845,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "1d69c7fc-fba8-40ad-92d1-3811b708cde1",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "epochs": 0.0431941570306258,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1721396736,
#             "modified_at": 1721396871,
#             "training_files": [
#                 "96d5e16c-d701-455c-8f76-82054d005325"
#             ],
#             "validation_files": [
#                 "cfc6dd29-f82e-48c0-8153-59e2313600c8"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:b6e34a5e:20240719:1d69c7fc",
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": 1310720,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 100,
#                 "cost": 2.6214,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 30344845,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "64192a7e-b09a-4917-8760-015f90073a7b",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "epochs": 0.0431941570306258,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "VALIDATED",
#             "job_type": "FT",
#             "created_at": 1721396729,
#             "modified_at": 1721396730,
#             "training_files": [
#                 "96d5e16c-d701-455c-8f76-82054d005325"
#             ],
#             "validation_files": [
#                 "cfc6dd29-f82e-48c0-8153-59e2313600c8"
#             ],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 100,
#                 "cost": 2.6214,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 30344845,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "adc708bd-877a-4201-bef1-16a1f1d93967",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "epochs": 0.0431941570306258,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1721396580,
#             "modified_at": 1721396718,
#             "training_files": [
#                 "96d5e16c-d701-455c-8f76-82054d005325"
#             ],
#             "validation_files": [
#                 "cfc6dd29-f82e-48c0-8153-59e2313600c8"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:b6e34a5e:20240719:adc708bd",
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": 1310720,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 100,
#                 "cost": 2.6214,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 30344845,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "372926dc-6cea-4198-8234-bd9c1856a2e5",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "epochs": 0.0431941570306258,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1721396234,
#             "modified_at": 1721396369,
#             "training_files": [
#                 "96d5e16c-d701-455c-8f76-82054d005325"
#             ],
#             "validation_files": [
#                 "cfc6dd29-f82e-48c0-8153-59e2313600c8"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:b6e34a5e:20240719:372926dc",
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": 1310720,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 140,
#                 "cost": 2.6214,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 30344845,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "bdfa52a5-3d66-4c51-bf37-b4ec6e4fa612",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "epochs": 0.0431941570306258,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1721383368,
#             "modified_at": 1721383502,
#             "training_files": [
#                 "962f783d-d38a-46e2-aa7a-8826bf1a42f1"
#             ],
#             "validation_files": [
#                 "1d6dbb85-09b6-4962-94f6-ae51f2353733"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:b6e34a5e:20240719:bdfa52a5",
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": 1310720,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 210,
#                 "cost": 2.6214,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 30344845,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "ded06fc3-7cf9-4753-a157-c2c3f9c0103b",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1720629436,
#             "modified_at": 1720629567,
#             "training_files": [
#                 "2f1e95bb-49cb-4998-9a2c-57a6093390ad"
#             ],
#             "validation_files": [
#                 "dfeaa63b-55c5-4850-afd5-61ffebf26782"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:b6e34a5e:20240710:ded06fc3",
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": 1310720,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "d1587e39-eb2a-43ac-9f6b-4fa4d0e45c31",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1720629167,
#             "modified_at": 1720629288,
#             "training_files": [
#                 "93b01e13-1834-4a8b-b60a-5538d59b2c93"
#             ],
#             "validation_files": [
#                 "2e1eb79d-388f-4c03-acfa-09b4bad51a91"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:b6e34a5e:20240710:d1587e39",
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": 1310720,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "e89017e4-d038-4056-a869-73ee9e87c79e",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 400,
#                 "learning_rate": 0.0003,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "mistral-small-latest",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1717576147,
#             "modified_at": 1717593291,
#             "training_files": [
#                 "8609ba12-353f-4277-87c8-0e1f7b6f72ce"
#             ],
#             "validation_files": [
#                 "0c5f525a-8dce-4c70-abfd-6bff1ec8e0c0"
#             ],
#             "fine_tuned_model": "ft:mistral-small-latest:b6e34a5e:20240605:e89017e4",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "test_api",
#                     "name": null,
#                     "run_name": "economist_style_guide_v8"
#                 }
#             ],
#             "trained_tokens": 52428800,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "3912b6ef-d2da-46b0-946f-56c243b8146f",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 200,
#                 "learning_rate": 0.0003,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "mistral-small-latest",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1717576026,
#             "modified_at": 1717584730,
#             "training_files": [
#                 "8609ba12-353f-4277-87c8-0e1f7b6f72ce"
#             ],
#             "validation_files": [
#                 "0c5f525a-8dce-4c70-abfd-6bff1ec8e0c0"
#             ],
#             "fine_tuned_model": "ft:mistral-small-latest:b6e34a5e:20240605:3912b6ef",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "test_api",
#                     "name": null,
#                     "run_name": "economist_style_guide_v7"
#                 }
#             ],
#             "trained_tokens": 26214400,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "7d0c9b8c-d3c7-4890-9788-ea12b917cb46",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 1500,
#                 "learning_rate": 7.5e-05,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "mistral-small-latest",
#             "status": "FAILED",
#             "job_type": "FT",
#             "created_at": 1717575567,
#             "modified_at": 1717575890,
#             "training_files": [
#                 "8609ba12-353f-4277-87c8-0e1f7b6f72ce"
#             ],
#             "validation_files": [
#                 "0c5f525a-8dce-4c70-abfd-6bff1ec8e0c0"
#             ],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "test_api",
#                     "name": null,
#                     "run_name": "economist_style_guide_v6"
#                 }
#             ],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "1d50c69f-4ed5-4888-a05d-cea08e8a1e49",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 800,
#                 "learning_rate": 7.5e-05,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "mistral-small-latest",
#             "status": "FAILED",
#             "job_type": "FT",
#             "created_at": 1717575373,
#             "modified_at": 1717575868,
#             "training_files": [
#                 "8609ba12-353f-4277-87c8-0e1f7b6f72ce"
#             ],
#             "validation_files": [
#                 "0c5f525a-8dce-4c70-abfd-6bff1ec8e0c0"
#             ],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "test_api",
#                     "name": null,
#                     "run_name": "economist_style_guide_v5"
#                 }
#             ],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "56578b71-9952-445e-a1c4-a77e8970a396",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 1000,
#                 "learning_rate": 7.5e-05,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "mistral-small-latest",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1717513741,
#             "modified_at": 1717519351,
#             "training_files": [
#                 "ab8a0a0e-699d-4084-a766-afd681c3e690"
#             ],
#             "validation_files": [
#                 "9e48568e-0f51-48d0-bc87-dc45aaba6f4e"
#             ],
#             "fine_tuned_model": "ft:mistral-small-latest:b6e34a5e:20240604:56578b71",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "test_api",
#                     "name": null,
#                     "run_name": "economist_style_guide_v4"
#                 }
#             ],
#             "trained_tokens": 16384000,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "ee1ab18b-5333-4bbd-b329-7e3ab6e0112f",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 1000,
#                 "learning_rate": 7.5e-05,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "mistral-small-latest",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1717513723,
#             "modified_at": 1717519428,
#             "training_files": [
#                 "ab8a0a0e-699d-4084-a766-afd681c3e690"
#             ],
#             "validation_files": [
#                 "9e48568e-0f51-48d0-bc87-dc45aaba6f4e"
#             ],
#             "fine_tuned_model": "ft:mistral-small-latest:b6e34a5e:20240604:ee1ab18b",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "test_api",
#                     "name": null,
#                     "run_name": "economist_style_guide_v4"
#                 }
#             ],
#             "trained_tokens": 16384000,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "068ac05d-c6a6-445d-af61-a32417b846b5",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 1500,
#                 "learning_rate": 0.0001,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "mistral-small-latest",
#             "status": "FAILED",
#             "job_type": "FT",
#             "created_at": 1717513568,
#             "modified_at": 1717513655,
#             "training_files": [
#                 "ab8a0a0e-699d-4084-a766-afd681c3e690"
#             ],
#             "validation_files": [
#                 "9e48568e-0f51-48d0-bc87-dc45aaba6f4e"
#             ],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "test_api",
#                     "name": null,
#                     "run_name": "economist_style_guide_v3"
#                 }
#             ],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "06f94d85-fb0f-443b-a4c3-9893ef4f8d41",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 1500,
#                 "learning_rate": 0.0001,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "mistral-small-latest",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1717498861,
#             "modified_at": 1717507124,
#             "training_files": [
#                 "d6a724d5-4792-444a-8aba-c412da7a0a1c"
#             ],
#             "validation_files": [
#                 "3e33c90e-6271-4307-b033-a7b72262957b"
#             ],
#             "fine_tuned_model": "ft:mistral-small-latest:b6e34a5e:20240604:06f94d85",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "test_api",
#                     "name": null,
#                     "run_name": "economist_style_guide_v3"
#                 }
#             ],
#             "trained_tokens": 24576000,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "7abfcf8f-6e99-486b-adc8-140cdc931874",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 1500,
#                 "learning_rate": 0.0003,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "mistral-small-latest",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1717493002,
#             "modified_at": 1717501386,
#             "training_files": [
#                 "d6a724d5-4792-444a-8aba-c412da7a0a1c"
#             ],
#             "validation_files": [
#                 "3e33c90e-6271-4307-b033-a7b72262957b"
#             ],
#             "fine_tuned_model": "ft:mistral-small-latest:b6e34a5e:20240604:7abfcf8f",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "test_api",
#                     "name": null,
#                     "run_name": "economist_style_guide_v2"
#                 }
#             ],
#             "trained_tokens": 24576000,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "9967f1a4-c985-4b29-acb8-05b17247ae1f",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 1000,
#                 "learning_rate": 0.0001,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "mistral-small-latest",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1717453634,
#             "modified_at": 1717459021,
#             "training_files": [
#                 "502d7435-c6a7-4245-b6c5-33cd5eaf1fc5"
#             ],
#             "validation_files": [
#                 "218f74d3-5961-460b-8452-59adc037231c"
#             ],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "test_api",
#                     "name": null,
#                     "run_name": "economist_style_guide_v1"
#                 }
#             ],
#             "trained_tokens": 16384000,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "adf036e3-69af-4762-bcd5-73b5226c2c64",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 1000,
#                 "learning_rate": 0.0005,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1717154159,
#             "modified_at": 1717164477,
#             "training_files": [
#                 "6438efb1-4ebc-4802-b67b-2f0069c5e4ec"
#             ],
#             "validation_files": [
#                 "467c19ae-6000-4148-8cae-b8d42aa6068a"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:b6e34a5e:20240531:adf036e3",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "test_api",
#                     "name": null,
#                     "run_name": "rapper_v0"
#                 }
#             ],
#             "trained_tokens": 32768000,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "15a987eb-9bd6-479c-82bb-3a2582d5d0f2",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 1000,
#                 "learning_rate": 0.0005,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1717153851,
#             "modified_at": 1717160771,
#             "training_files": [
#                 "4a9a79b0-609c-4f94-b54e-82d0f9ef6037"
#             ],
#             "validation_files": [
#                 "dd70766f-6d25-4e6f-a045-8753e9dfd896"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:b6e34a5e:20240531:15a987eb",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "test_api",
#                     "name": null,
#                     "run_name": "socrates_v0"
#                 }
#             ],
#             "trained_tokens": 32768000,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "00428354-ed52-450f-a299-0b47935d3ceb",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 1000,
#                 "learning_rate": 0.0005,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "mistral-small-latest",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1717153185,
#             "modified_at": 1717171939,
#             "training_files": [
#                 "d1e4d2fc-c6ba-46ce-a070-0270b7a30012"
#             ],
#             "validation_files": [
#                 "74884504-4a67-4806-adab-36a15d5e547a"
#             ],
#             "fine_tuned_model": "ft:mistral-small-latest:b6e34a5e:20240531:00428354",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "test_api",
#                     "name": null,
#                     "run_name": "call_assistant_v0"
#                 }
#             ],
#             "trained_tokens": 16384000,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "50d006d4-3983-45ad-a071-56e070624eef",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 1000,
#                 "learning_rate": 0.0005,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1717153161,
#             "modified_at": 1717158631,
#             "training_files": [
#                 "d1e4d2fc-c6ba-46ce-a070-0270b7a30012"
#             ],
#             "validation_files": [
#                 "74884504-4a67-4806-adab-36a15d5e547a"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:b6e34a5e:20240531:50d006d4",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "test_api",
#                     "name": null,
#                     "run_name": "call_assistant_v0"
#                 }
#             ],
#             "trained_tokens": 32768000,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "4ffddbce-caca-4dda-b49b-c1868213d141",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 1000,
#                 "learning_rate": 0.0005,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1717150637,
#             "modified_at": 1717154822,
#             "training_files": [
#                 "935a5891-500f-40d8-897d-bf917fcf9d51"
#             ],
#             "validation_files": [
#                 "898df146-9f3b-48d3-9a4a-1740cff98748"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:b6e34a5e:20240531:4ffddbce",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "test_api",
#                     "name": null,
#                     "run_name": "docstral_v3"
#                 }
#             ],
#             "trained_tokens": 32768000,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "48314f29-75f3-4b17-a8c6-bd8ce9128824",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 300,
#                 "learning_rate": 0.0001,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1717148417,
#             "modified_at": 1717150061,
#             "training_files": [
#                 "935a5891-500f-40d8-897d-bf917fcf9d51"
#             ],
#             "validation_files": [
#                 "898df146-9f3b-48d3-9a4a-1740cff98748"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:b6e34a5e:20240531:48314f29",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "test_api",
#                     "name": null,
#                     "run_name": "docstral_v2"
#                 }
#             ],
#             "trained_tokens": 9830400,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "a29e61db-40b2-42bf-9b2f-202059650474",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 300,
#                 "learning_rate": 0.0001,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1717113860,
#             "modified_at": 1717115931,
#             "training_files": [
#                 "38fb0142-3811-4e17-b24b-7e62e8efda42"
#             ],
#             "validation_files": [
#                 "a37a2cef-1404-46bf-98f4-2081abdb3470"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:b6e34a5e:20240531:a29e61db",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "patrick_api_test_docstral",
#                     "name": null,
#                     "run_name": "docstral"
#                 }
#             ],
#             "trained_tokens": 9830400,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "f88f46b9-c3df-4fd3-b991-0cc89201e1e1",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 300,
#                 "learning_rate": 0.0001,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "mistral-small-latest",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1717113489,
#             "modified_at": 1717125723,
#             "training_files": [
#                 "38fb0142-3811-4e17-b24b-7e62e8efda42"
#             ],
#             "validation_files": [
#                 "a37a2cef-1404-46bf-98f4-2081abdb3470"
#             ],
#             "fine_tuned_model": "ft:mistral-small-latest:b6e34a5e:20240530:f88f46b9",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "patrick_api_test_docstral",
#                     "name": null,
#                     "run_name": "docstral"
#                 }
#             ],
#             "trained_tokens": 4915200,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "6ac4eb76-59a4-4840-a710-16667985b6bb",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "mistral-small-latest",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1717094735,
#             "modified_at": 1717121456,
#             "training_files": [
#                 "e44bcf12-b0fc-49c9-80dc-3095ec15e51e"
#             ],
#             "validation_files": [
#                 "e44bcf12-b0fc-49c9-80dc-3095ec15e51e"
#             ],
#             "fine_tuned_model": "ft:mistral-small-latest:b6e34a5e:20240530:6ac4eb76",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "patrick_api_test_mistral-small-latest",
#                     "name": null,
#                     "run_name": "ultrachat_"
#                 }
#             ],
#             "trained_tokens": 163840,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "f254559d-6f87-4ea9-83c1-cb98458a6046",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1717094357,
#             "modified_at": 1717095416,
#             "training_files": [
#                 "dec8c42d-fa77-46b8-96a4-66b23720edac"
#             ],
#             "validation_files": [
#                 "dec8c42d-fa77-46b8-96a4-66b23720edac"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:b6e34a5e:20240530:f254559d",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "patrick_api_test_open-mistral-7b",
#                     "name": null,
#                     "run_name": "ultrachat_"
#                 }
#             ],
#             "trained_tokens": 327680,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "8f3d5c05-9beb-4a9c-9351-dbbd994e2fea",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "epochs": null,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1717092822,
#             "modified_at": 1717092973,
#             "training_files": [
#                 "573626c4-2c77-4707-acec-afed94b8e0ff"
#             ],
#             "validation_files": [
#                 "fbff9bc2-d938-4fda-bc84-26e551682ce1"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:b6e34a5e:20240530:8f3d5c05",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "patrick_test_dummy",
#                     "name": null,
#                     "run_name": null
#                 }
#             ],
#             "trained_tokens": 327680,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": null,
#                 "cost": null,
#                 "cost_currency": null,
#                 "train_tokens_per_step": null,
#                 "train_tokens": null,
#                 "data_tokens": null,
#                 "estimated_start_time": null
#             }
#         }
#     ],
#     "OBJECT": "list"
# }

# %%
# Retrieve a jobs
retrieved_jobs = client.fine_tuning.jobs.get(job_id = created_jobs.id)
pprint(retrieved_jobs)
# Out:
# {
#     "id": "20178c3c-d75b-428e-b20d-7d39aa2b7468",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.0001,
#         "epochs": 0.0431941570306258,
#         "fim_ratio": null
#     },
#     "model": "open-mistral-7b",
#     "status": "SUCCESS",
#     "job_type": "FT",
#     "created_at": 1721405548,
#     "modified_at": 1721405693,
#     "training_files": [
#         "ec5af16a-77fe-4e14-ad09-47ead2848ce6"
#     ],
#     "validation_files": [
#         "d0c643a2-a57c-4031-bda7-5c9d6c3ec3e4"
#     ],
#     "fine_tuned_model": "ft:open-mistral-7b:b6e34a5e:20240719:20178c3c",
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": 1310720,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 120,
#         "cost": 2.6214,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 131072,
#         "train_tokens": 1310720,
#         "data_tokens": 30344845,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1721405693
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1721405549
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1721405549
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1721405549
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1721405548
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1721405548
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 0.851776,
#                 "valid_loss": 0.92623,
#                 "valid_mean_token_accuracy": 1.900304
#             },
#             "step_number": 10,
#             "created_at": 1721405660
#         }
#     ]
# }

# %% [markdown]
# ## Use a fine-tuned model

# %%
chat_response = client.chat.complete(
    model = retrieved_jobs.fine_tuned_model,
    messages = [{"role":'user', "content":'What is the best French cheese?'}]
)

# %%
pprint(chat_response)
# Out:
# {
#     "id": "1fac96713fd74799922712e34e009f81",
#     "object": "chat.completion",
#     "model": "ft:open-mistral-7b:b6e34a5e:20240719:20178c3c",
#     "usage": {
#         "prompt_tokens": 10,
#         "completion_tokens": 73,
#         "total_tokens": 83
#     },
#     "created": 1721405725,
#     "choices": [
#         {
#             "index": 0,
#             "finish_reason": "stop",
#             "message": {
#                 "content": "There isn't a single \"best\" French cheese as there are hundreds of different types of cheese to choose from, each with its unique taste and texture. Some popular French cheeses include Brie, Camembert, Roquefort, Comt\u00e9, and Ch\u00e8vre. Try different cheeses to find out the one you like best!",
#                 "tool_calls": null,
#                 "prefix": false,
#                 "role": "assistant"
#             }
#         }
#     ]
# }

# %% [markdown]
# ## Integration with Weights and Biases
# We can also offer support for integration with Weights & Biases (W&B) to monitor and track various metrics and statistics associated with our fine-tuning jobs. To enable integration with W&B, you will need to create an account with W&B and add your W&B information in the “integrations” section in the job creation request:

# %%
client.fine_tuning.jobs.create(
    model="open-mistral-7b",
    training_files=[{"file_id": ultrachat_chunk_train.id, "weight": 1}],
    validation_files=[ultrachat_chunk_eval.id],
    hyperparameters={"training_steps": 10, "learning_rate": 0.0001},
    integrations=[
        {
            "project": "<value>",
            "api_key": "<value>",
        }
    ]
)
